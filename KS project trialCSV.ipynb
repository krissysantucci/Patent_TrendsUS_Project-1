# %%
import requests
import json
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# %%
file_one_csv = "fileOne.csv"

# %%
uspto_df = pd.read_csv(file_one_csv, encoding = "ISO-8859-1")

low_memory = False

uspto_df

uspto_df['Patent Year'] = uspto_df['Patent Year'].astype(str)
# Out:
# C:\Users\kdsan\terminal_prework\lib\site-packages\IPython\core\interactiveshell.py:3058: DtypeWarning: Columns (0,6,7) have mixed types. Specify dtype option on import or set low_memory=False.
#   interactivity=interactivity, compiler=compiler, result=result)

# %%
colors = ["red", "blue","green", "yellow", "orange", "indigo", "turquoise", "lawngreen", "fuchsia", "gold"]

# %%
Top_Ten_Org = uspto_df.groupby(['Assignee Organization']).agg({'Patent ID': 'count'})
Ranked_Org = Top_Ten_Org.nlargest(10, 'Patent ID')
Renamed_Total = Ranked_Org.rename(columns={"Patent ID":"Total Patents"})
Top_Ten = Renamed_Total.plot(kind='bar',color=[colors],figsize=(20,20))
Top_Ten.set_xlabel("Assignee Organization")
Top_Ten.set_ylabel("Number of Patents")
Ranked_Org
plt.savefig('Top_Ten_Orgs', dpi=100)
plt.show()

# %%
#US Company
type2_df = uspto_df.loc[uspto_df["Assignee Type"] == 2, :]
type2_counts = type2_df.groupby(['Patent Year']).agg({'Patent ID': 'count'})
renamed_type2_df = type2_counts.rename(columns={"Patent ID":"US Company"})
#year2_counts_chart = renamed_type2_df.plot(kind='line',figsize=(15,7), linestyle='--', linewidth=3.0)

renamed_type2_df

#x_axis = range(len("Patent Year"))
#tick_locations = [value for value in x_axis]
#plt.xticks(tick_locations, ["2000","2001","2002","2003","2004","2005","2006","2007","2008","2009","2010","2011","2012","2013","2014","2015","2016","2017","2018","2019"])
#plt.savefig('US Company', dpi=100)
#plt.show()
# Out:
#              US Company
# Patent Year
# 2000              78081
# 2001              81239
# 2002              79205
# 2003              84950
# 2004              80206
# 2005              69560
# 2006              88914
# 2007              81227
# 2008              82264
# 2009              84992
# 2010             107407
# 2011             107776
# 2012             119264
# 2013             129371
# 2014             148106
# 2015             144614
# 2016             149852
# 2017             158149
# 2018             152635
# 2019             136001

# %%
#Foreign Company
type3_df = uspto_df.loc[uspto_df["Assignee Type"] == 3, :]
type3_counts = type3_df.groupby(['Patent Year']).agg({'Patent ID': 'count'})
renamed_type3 = type3_counts.rename(columns={"Patent ID":"Foreign Company"})
year3_counts_chart = renamed_type3.plot(kind='line',figsize=(15,7), linestyle='--', linewidth=3.0)

#x_axis = range(len("Patent Year"))
#tick_locations = [value for value in x_axis]
#plt.xticks(tick_locations, ["2000","2001","2002","2003","2004","2005","2006","2007","2008","2009","2010","2011","2012","2013","2014","2015","2016","2017","2018","2019"])
plt.savefig('Foreign Company', dpi=100)
plt.show()

# %%
#US Individual
type4_df = uspto_df.loc[uspto_df["Assignee Type"] == 4, :]
type4_counts = type4_df.groupby(['Patent Year']).agg({'Patent ID': 'count'})
renamed_type4 = type4_counts.rename(columns={"Patent ID":"US Individual"})
year4_counts_chart = renamed_type4.plot(kind='line',figsize=(15,7), linestyle='--', linewidth=3.0)

#x_axis = range(len("Patent Year"))
#tick_locations = [value for value in x_axis]
#plt.xticks(tick_locations, ["2000","2001","2002","2003","2004","2005","2006","2007","2008","2009","2010","2011","2012","2013","2014","2015","2016","2017","2018","2019"])
plt.savefig('US Individual', dpi=100)
plt.show()

# %%
#Foreign Individual
type5_df = uspto_df.loc[uspto_df["Assignee Type"] == 5, :]
type5_counts = type5_df.groupby(['Patent Year']).agg({'Patent ID': 'count'})
renamed_type5 = type5_counts.rename(columns={"Patent ID":"Foreign Individual"})
year5_counts_chart = renamed_type5.plot(kind='line',figsize=(15,7), linestyle='--', linewidth=3.0)

#x_axis = range(len("Patent Year"))
#tick_locations = [value for value in x_axis]
#plt.xticks(tick_locations, ["2000","2001","2002","2003","2004","2005","2006","2007","2008","2009","2010","2011","2012","2013","2014","2015","2016","2017","2018","2019"])
plt.savefig('Foreign Individual', dpi=100)
plt.show()

# %%
#US Government
type6_df = uspto_df.loc[uspto_df["Assignee Type"] == 6, :]
type6_counts = type6_df.groupby(['Patent Year']).agg({'Patent ID': 'count'})
renamed_type6 = type6_counts.rename(columns={"Patent ID":"US Government"})
year6_counts_chart = renamed_type6.plot(kind='line',figsize=(15,7), linestyle='--', linewidth=3.0)

#x_axis = range(len("Patent Year"))
#tick_locations = [value for value in x_axis]
#plt.xticks(tick_locations, ["2000","2001","2002","2003","2004","2005","2006","2007","2008","2009","2010","2011","2012","2013","2014","2015","2016","2017","2018","2019"])
plt.savefig('US Government', dpi=100)
plt.show()

# %%
#Foreign Government
type7_df = uspto_df.loc[uspto_df["Assignee Type"] == 7, :]
type7_counts = type7_df.groupby(['Patent Year']).agg({'Patent ID': 'count'})
renamed_type7 = type7_counts.rename(columns={"Patent ID":"Foreign Government"})
year7_counts_chart = renamed_type7.plot(kind='line',figsize=(15,7), linestyle='--', linewidth=3.0)

#x_axis = range(len("Patent Year"))
#tick_locations = [value for value in x_axis]
#plt.xticks(tick_locations, ["2000","2001","2002","2003","2004","2005","2006","2007","2008","2009","2010","2011","2012","2013","2014","2015","2016","2017","2018","2019"])
plt.savefig('Foreign Government', dpi=100)
plt.show()

# %%
#US Company
type2_df = uspto_df.loc[uspto_df["Assignee Type"] == 2, :]
type2_counts = type2_df.groupby(['Patent Year']).agg({'Patent ID': 'count'})
renamed_type2_df = type2_counts.rename(columns={"Patent ID":"US Company"})
#year2_counts_chart = renamed_type2_df.plot(kind='line',figsize=(15,7), linestyle='--')
#renamed_type2_df

#Foreign Company
type3_df = uspto_df.loc[uspto_df["Assignee Type"] == 3, :]
type3_counts = type3_df.groupby(['Patent Year']).agg({'Patent ID': 'count'})
renamed_type3 = type3_counts.rename(columns={"Patent ID":"Foreign Company"})
#year3_counts_chart = renamed_type3.plot(kind='line',figsize=(15,7), linestyle='--')

#US Individual
type4_df = uspto_df.loc[uspto_df["Assignee Type"] == 4, :]
type4_counts = type4_df.groupby(['Patent Year']).agg({'Patent ID': 'count'})
renamed_type4 = type4_counts.rename(columns={"Patent ID":"US Individual"})
#year4_counts_chart = renamed_type4.plot(kind='line',figsize=(15,7), linestyle='--'))

#Foreign Individual
type5_df = uspto_df.loc[uspto_df["Assignee Type"] == 5, :]
type5_counts = type5_df.groupby(['Patent Year']).agg({'Patent ID': 'count'})
renamed_type5 = type5_counts.rename(columns={"Patent ID":"Foreign Individual"})
#year5_counts_chart = renamed_type5.plot(kind='line',figsize=(15,7), linestyle='--'))

#US Government
type6_df = uspto_df.loc[uspto_df["Assignee Type"] == 6, :]
type6_counts = type6_df.groupby(['Patent Year']).agg({'Patent ID': 'count'})
renamed_type6 = type6_counts.rename(columns={"Patent ID":"US Government"})
#year6_counts_chart = renamed_type6.plot(kind='line',figsize=(15,7), linestyle='--'))

#Foreign Government
type7_df = uspto_df.loc[uspto_df["Assignee Type"] == 7, :]
type7_counts = type7_df.groupby(['Patent Year']).agg({'Patent ID': 'count'})
renamed_type7 = type7_counts.rename(columns={"Patent ID":"Foreign Government"})
#year7_counts_chart = renamed_type7.plot(kind='line',figsize=(15,7), linestyle='--'))

merge_table = pd.merge(renamed_type2_df,renamed_type3, on='Patent Year')
merge_table2 = pd.merge(merge_table, renamed_type4, on='Patent Year')
merge_table3 = pd.merge(merge_table2, renamed_type5, on='Patent Year')
merge_table4 = pd.merge(merge_table3, renamed_type6, on='Patent Year')
merge_table_final = pd.merge(merge_table4, renamed_type7, on='Patent Year')
merge_table_final
# Out:
#              US Company  Foreign Company  US Individual  Foreign Individual  \
# Patent Year
# 2000              78081            61079            801                 311
# 2001              81239            67133            856                 439
# 2002              79205            80450            757                 576
# 2003              84950            82167            829                 560
# 2004              80206            79096            865                 436
# 2005              69560            70940            669                 467
# 2006              88914            86976            865                 459
# 2007              81227            83222            689                 411
# 2008              82264            89397            636                 396
# 2009              84992            91451            672                 421
# 2010             107407           115761            852                 558
# ...

# %%
merge_table = pd.merge(renamed_type2_df,renamed_type3, on='Patent Year')
USForeign_comp_chart = merge_table.plot(kind='line', figsize=(15,7), Linestyle='--', linewidth=3.0)
plt.savefig('US vs Foreign Company', dpi=100)
merge_table2 = pd.merge(renamed_type5, renamed_type4, on='Patent Year')
USForeign_ind_chart = merge_table2.plot(kind='line', figsize=(15,7), Linestyle='--', linewidth=3.0)
plt.savefig('US vs Foreign Individual', dpi=100)
merge_table3 = pd.merge(renamed_type6, renamed_type7, on='Patent Year')
USForeign_govt_chart = merge_table3.plot(kind='line', figsize=(15,7), Linestyle='--', linewidth=3.0)
plt.savefig('US vs Foreign Government', dpi=100)
plt.show
# Out:
# <function matplotlib.pyplot.show(*args, **kw)>

# %%
Yearly_Patents = uspto_df.groupby(['Patent Year']).agg({'Patent ID': 'count'})
Renamed_Yearly_Patents = Yearly_Patents.rename(columns={"Patent ID":"Total Patents"})
print(Renamed_Yearly_Patents)

Yearly_Patents_Chart = Renamed_Yearly_Patents.plot(kind='line',figsize=(15,7), linewidth=3.0, color='lawngreen')
Yearly_Patents_Chart.set_xlabel("Year")
Yearly_Patents_Chart.set_ylabel("Number of Patents")

plt.savefig('Total Patents', dpi=100)
plt.show()
# Out:
#              Total Patents
# Patent Year
# 2000                176192
# 2001                184172
# 2002                184494
# 2003                190865
# 2004                181413
# 2005                157829
# 2006                196489
# 2007                182978
# 2008                188726
# 2009                192052
# 2010                244599
# 2011                248101
# 2012                277285
# 2013                303658
# 2014                334079
# 2015                326969
# 2016                334674
# 2017                352587
# 2018                341104
# 2019                300386

# %%
#Line Graph
chemical_df = uspto_df.loc[uspto_df["Category"] == "Chemical", :]
chemical_counts = chemical_df.groupby(['Patent Year']).agg({'Patent ID': 'count'})
renamed_chemical_df = chemical_counts.rename(columns={"Patent ID":"Chemical"})
#chemical_counts_chart = renamed_chemical_df.plot(kind='line')

computer_df = uspto_df.loc[uspto_df["Category"] == "Cmp&Cmm", :]
computer_counts = computer_df.groupby(['Patent Year']).agg({'Patent ID': 'count'})
renamed_computer_df = computer_counts.rename(columns={"Patent ID":"Computers and Communication"})
#computer_counts_chart = renamed_computer_df.plot(kind='line')

drugs_df = uspto_df.loc[uspto_df["Category"] == "Drgs&Med", :]
drugs_counts = drugs_df.groupby(['Patent Year']).agg({'Patent ID': 'count'})
renamed_drugs_df =drugs_counts.rename(columns={"Patent ID":"Drugs and Medical"})
#drugs_counts_chart = renamed_drugs_df.plot(kind='line')

elec_df = uspto_df.loc[uspto_df["Category"] == "Elec", :]
elec_counts = elec_df.groupby(['Patent Year']).agg({'Patent ID': 'count'})
renamed_elec_df = elec_counts.rename(columns={"Patent ID":"Electrical"})
#elec_counts_chart = renamed_elec_df.plot(kind='line')

mech_df = uspto_df.loc[uspto_df["Category"] == "Mech", :]
mech_counts = mech_df.groupby(['Patent Year']).agg({'Patent ID': 'count'})
renamed_mech_df = mech_counts.rename(columns={"Patent ID":"Mechanical"})
#mech_counts_chart = renamed_mech_df.plot(kind='line')

others_df = uspto_df.loc[uspto_df["Category"] == "Others", :]
others_counts = others_df.groupby(['Patent Year']).agg({'Patent ID': 'count'})
renamed_others_df = others_counts.rename(columns={"Patent ID":"Others"})
#others_counts_chart = renamed_others_df.plot(kind='line')

#Bar Graph
Total_Category_Title = uspto_df.groupby(['Category']).agg({'Patent ID': 'count'})
Renamed_Total = Total_Category_Title.rename(columns={"Patent ID":"Total Patents"})
Total_Category_Chart = Renamed_Total.plot(kind='bar')
Total_Category_Chart.set_xlabel("Category Title")
Total_Category_Chart.set_ylabel("Number of Patents")
#plt.show()
# Out:
# Text(0, 0.5, 'Number of Patents')

# %%
merge_table = pd.merge(renamed_chemical_df,renamed_computer_df, on='Patent Year')
merge_table2 = pd.merge(merge_table,renamed_drugs_df, on='Patent Year')
merge_table3 = pd.merge(merge_table2,renamed_elec_df, on='Patent Year')
merge_table4 = pd.merge(merge_table3,renamed_mech_df, on='Patent Year')
merge_table_final = pd.merge(merge_table4,renamed_others_df, on='Patent Year')
merge_final_chart = merge_table_final.plot(kind='line',figsize=(15,7), linewidth=3.0)
plt.savefig('Patent Catagories over Time', dpi=100, figsize = (20,35))
#Bar Graph
Total_Category_Title = uspto_df.groupby(['Category']).agg({'Patent ID': 'count'})
Renamed_Total = Total_Category_Title.rename(columns={"Patent ID":"Total Patents"})
Total_Category_Chart = Renamed_Total.plot(kind='bar',figsize = (15,7), color=[colors])
Total_Category_Chart.set_xlabel("Category Title")
Total_Category_Chart.set_ylabel("Number of Patents")
plt.savefig('Number of Patent per Category', dpi=100)
plt.show()

# %%
#Line Graph
Yearly_Subcategory_Title = uspto_df.groupby(['Patent Year','Subcategory']).agg({'Patent ID': 'count'})
#Yearly_Subcategory_Title

#Bar Graph
Total_Subcategory_Title = uspto_df.groupby(['Subcategory']).agg({'Patent ID': 'count'})
Ranked_Subcategory = Total_Subcategory_Title.nlargest(10, 'Patent ID')
Total_Subcategory_Chart = Ranked_Subcategory.plot(kind='bar',color=[colors], figsize=(15,7))
Total_Subcategory_Chart.set_xlabel("Subcategory Types")
Total_Subcategory_Chart.set_ylabel("Number of Patents")
plt.savefig('Patents per Sub Category', dpi=100)
plt.show()
plt.tight_layout()

# %%
#Line Graph
Yearly_Assignee_Country = uspto_df.groupby(['Patent Year','Assignee Country']).agg({'Patent ID': 'count'})
#Yearly_Assignee_Country

#Bar Chart
Total_Assignee_Country = uspto_df.groupby(['Assignee Country']).agg({'Patent ID': 'count'})
Ranked_Assignee_Country = Total_Assignee_Country.nlargest(10, 'Patent ID')
Total_Country_Chart = Ranked_Assignee_Country.plot(kind='bar',color=[colors], figsize=(15,7))
Total_Country_Chart.set_xlabel("Country of Origin")
Total_Country_Chart.set_ylabel("Number of Patents")
plt.savefig('Country of Origin', dpi=100)

USCountry_df = uspto_df.loc[uspto_df["Assignee Country"] == "US", :]
USC_counts = USCountry_df.groupby(['Patent Year']).agg({'Patent ID': 'count'})
renamed_USC_df = USC_counts.rename(columns={"Patent ID":"US"})
#USC_counts_chart = renamed_USC_df.plot(kind='line')

JPCountry_df = uspto_df.loc[uspto_df["Assignee Country"] == "JP", :]
JPC_counts = JPCountry_df.groupby(['Patent Year']).agg({'Patent ID': 'count'})
renamed_JPC_df = JPC_counts.rename(columns={"Patent ID":"Japan"})
#JPC_counts_chart = renamed_JPC_df.plot(kind='line')

CNCountry_df = uspto_df.loc[uspto_df["Assignee Country"] == "CN", :]
CNC_counts = CNCountry_df.groupby(['Patent Year']).agg({'Patent ID': 'count'})
renamed_CNC_df = CNC_counts.rename(columns={"Patent ID":"China"})
#CNC_counts_chart = renamed_CNC_df.plot(kind='line')

DECountry_df = uspto_df.loc[uspto_df["Assignee Country"] == "DE", :]
DEC_counts = DECountry_df.groupby(['Patent Year']).agg({'Patent ID': 'count'})
renamed_DEC_df = DEC_counts.rename(columns={"Patent ID":"Denmark"})
#DEC_counts_chart = renamed_DEC_df.plot(kind='line')

plt.show()
plt.tight_layout()

# %%
merge_table = pd.merge(renamed_USC_df,renamed_JPC_df, on='Patent Year')
merge_table2 = pd.merge(merge_table,renamed_CNC_df, on='Patent Year')
merge_table_final = pd.merge(merge_table2,renamed_DEC_df, on='Patent Year')
merge_final_chart = merge_table_final.plot(kind='line',figsize=(15,7), linewidth=3.0)
plt.savefig('Comparing Countries', dpi=100)
plt.show()
plt.tight_layout()

# %%
Total_Assignee_City = uspto_df.groupby(['Assignee City']).agg({'Patent ID': 'count'})
Ranked_Assignee_City = Total_Assignee_City.nlargest(10, 'Patent ID')
Total_City_Chart = Ranked_Assignee_City.plot(kind='bar',figsize=(15,7), color=[colors])
Total_City_Chart.set_xlabel("City")
Total_City_Chart.set_ylabel("Number of Patents")
plt.tight_layout()
plt.savefig('City of Origin', dpi=100)
plt.show()
